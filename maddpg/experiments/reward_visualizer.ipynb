# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
# import pickle file _rewards.pkl and plot the rewards
# %matplotlib inline
# with open('.\learning_curves\_agrewards.pkl', 'rb') as f:

#     rewards = pickle.load(f)
# load pickle file rewards.pkl and plot the rewards
# with open('rewards_self-interested.pkl', 'rb') as f:
with open('rewards.pkl', 'rb') as f:
    rewards = pickle.load(f)

# %%
rewards = np.array(rewards)
rewards.shape
# Out:
# (500000, 3)

# %%
# scatter plot of rewards
plt.scatter(np.arange(len(rewards[:,0])), rewards[:,0], alpha=0.01, s=2)
# plt.scatter(np.arange(len(rewards[1])), rewards[0], alpha=0.3, s=2)
# plt.scatter(np.arange(len(rewards[2])), rewards[0], alpha=0.3, s=2)
# rewards = np.array(rewards)

# plot moving average of rewards for all (remember rewards is a 2 dimensional array)
# plt.plot(rewards, alpha=0.4)
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Sum of Rewards per Episode')
plt.show()
